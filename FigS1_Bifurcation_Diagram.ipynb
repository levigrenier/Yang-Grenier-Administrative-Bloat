# %% [markdown]
# # FigS1_Bifurcation_Diagram

# %%
import numpy as np
import scipy as sp
from scipy.optimize import minimize
import pandas as pd
from scipy.optimize import fsolve
import matplotlib.pyplot as plt
import matplotlib as mpl
import matplotlib.patches as mpatches
from matplotlib.lines import Line2D
import matplotlib.colors as colors
from matplotlib.colors import LinearSegmentedColormap
import ipynb.fs.defs.Functions_Equations_Equilibrium_Simulation as baseFuncs
import ipynb.fs.defs.Functions_Equilibria_Along_Parameters as bifurcFuncs

# %% [markdown]
# ## Evaluate Parameter Slice

# %%
para = baseFuncs.paraReset()
#para['gamma_p'] = 1
param_label = "gamma_c"
lower = 0.01
upper = 1
data1 = bifurcFuncs.paramSlice(param_label, lower, upper, para, param_mesh = 501, init_mesh = 20, xtol = 1e-6, stab_slice = False)
# Out:
# C:\Users\grenier\MIT Dropbox\Levi Grenier\Rule dynamics\Up to date code\20260212 Replication Update\Functions_Equations_Equilibrium_Simulation.ipynb:240: RuntimeWarning: invalid value encountered in scalar power
#   "                return np.nan\n",

# %% [markdown]
# ## Plot

# %%
bifurcFuncs.plotParamSlice(data1, plot_type = 1, show_rules = True, show_sum = False, 
               saveFig = False, saveName = "Bifurc_wrt_gamma_c_default_gamma_p_mesh_501.png", log_y = True)
